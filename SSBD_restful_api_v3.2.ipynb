# %% [markdown]
# ## Examples to access SSBD using REST API version 3.2
#
# The following are some examples of accessing SSBD via REST API directly using Python.

# %%
# %config InlineBackend.figure_formats=['png']

# %%
from IPython.display import display

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d

# %%
# %matplotlib inline

# %%
from math import sqrt

# %% [markdown]
# ## Loading ivisual library allows iPython to use VPython to display 3D graphics
#
# * Installing ivisual can be found here https://github.com/mwcraig/ivisual-notebook-info

# %%
from ivisual import *
# Out:
# <div id="scene0"><div id="glowscript" class="glowscript"></div></div>

# %% [markdown]
# ## Loading json library allows iPython to deal with JSON formatted data

# %%
import json

# %% [markdown]
# ## Loading requests to access REST API

# %%
import requests

# %% [markdown]
# # Requesting SSBD_REST API
# * Using data
# * finding localID that contains the phrase wt (i.e. wild type)

# %%
#resp = requests.get('http://ssbd1.qbic.riken.jp/SSBD/api/v3/data/?format=json;localID__icontains=wt')
#resp = requests.get('http://172.21.20.193:8000/SSBD/api/v3/data/?format=json;localID__icontains=wt')
resp = requests.get('http://host.docker.internal:8000/SSBD/api/v3/data/?format=json;localID__icontains=wt')



print("resp:", resp)
if resp.status_code != 200:
    # This means something went wrong.
    raise ApiError('GET /tasks/ {}'.format(resp.status_code))

#print resp.text
bdmldata = resp.json()
#for todo_item in bdmldata:
#    print('{} {}'.format(todo_item['id'], todo_item['summary']))
# Out:
# (MainThread) Starting new HTTP connection (1): host.docker.internal
# (MainThread) http://host.docker.internal:8000 "GET /SSBD/api/v3/data/?format=json;localID__icontains=wt HTTP/1.1" 200 None
# resp: <Response [200]>

# %%
print(type(bdmldata))
#print "bdmldata=", bdmldata
print("meta=", bdmldata['meta'])
print("total_count=", bdmldata['meta']['total_count'])
#print "limit=", bdmldata['meta']['limit']
#print "objects=", bdmldata['objects']
for i in bdmldata['objects']:
#    print "i=", i
    print("description=", i['description'])
    print("basedon=", i['basedon'])
    print("bdmlID=", i['bdmlID'])
    print("datatype=", i['datatype'])
    print("dblink=", i['dblink'])
    print("gene=", i['gene'])
    print("license=", i['license'])
    print("method_summary=", i['method_summary'])
    print("organism=", i['organism'])
    print("localID=", i['localID'])
    print("orf=", i['orf'])
    print("release=", i['release'])
    print("schema_ver=", i['schema_ver'])
    print("------------------------")
# Out:
# <class 'dict'>
# meta= {'limit': 20, 'next': '/SSBD/api/v3/data/?localID__icontains=wt&offset=20&limit=20&format=json', 'offset': 0, 'previous': None, 'total_count': 53}
# total_count= 53
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= 7e0d3df0-573b-48d2-9e5a-7736f78e9e55
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030127_01
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= 203b5c86-2280-437b-8807-d97c8126f79a
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030131_01
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= 44a49534-e76c-4641-b78f-762fb354c8d6
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030131_03
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= bb1b2688-cad0-4dc6-a7a4-4ff6f34b275b
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030203_01
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= 521ef3a0-3121-4de5-9022-8c48691ee4ce
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030116_02
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= 38ae8179-5c65-4c8a-9fa8-2a892ac3eb9d
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030124_02
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= a423f384-9d39-4240-94ee-7f5c31581986
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030210_01
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= ef48f7c4-c999-48ba-aae5-91e8d537b8ef
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030210_02
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= cc5f358b-870d-44ee-9304-78f7c1d6ed5f
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030210_03
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= 43250fa2-f24b-4aee-8f14-d752b5c995c4
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030212_01
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= b460470d-df02-4b9f-a3e7-7b1a66b6e341
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030212_02
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= 0c0a1c04-fb42-4271-94fd-b4600addfa9c
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030213_02
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= 34574809-7b05-4167-857a-6e81bbbae160
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030204_03
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= 52af1b59-f845-4836-a85c-d66f849dff70
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030207_01
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= 570467a6-b06a-4446-8c16-0eb20c8cce61
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030207_02
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= 9c0f598c-5cb1-4d8c-8d78-7f2668ed1307
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030217_04
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= 352f4bcb-6095-4cc4-a2fa-0451bae5f33d
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030218_01
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= b415c4a6-b8a1-44c5-9411-9bad72d4d652
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030218_02
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= efff89ef-a72a-4cfc-a90d-6ddf106eb4a5
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030218_04
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------
# description= quantitative information about nuclear division dynamics in wild-type embryo
# basedon= Experiment
# bdmlID= 6165cc05-aeff-4a64-95ac-1065eb14cc94
# datatype= nuclear division dynamics
# dblink= http://so.qbic.riken.jp/wddd/
# gene= None
# license= CC BY-SA
# method_summary= See details in Kyoda et al. (2013) Nucleic Acids Res 41, D732-D737.
# organism= C. elegans
# localID= wt(N2)030221_01
# orf= None
# release= 2017-12-20
# schema_ver= 3.000
# ------------------------

# %% [markdown]
# ## Example of using REST API to get numerical data
#
# Display a time point in 3D
# Using data set from Bao et al. (2006) Automated cell lineage tracing in Caenorhabditis elegans. Proc. Natl. Acad. Sci. U.S.A., 103(8), 2707-2712  http://www.ncbi.nlm.nih.gov/pubmed/16477039
#
# http://ssbd.qbic.riken.jp/search3/800faa21-c28c-4b72-bd12-d41f2eed02e8/

# %%
# version 3.2
#urlbase = 'http://ssbd1.qbic.riken.jp:8000/SSBD/api/v3/'
#urlbase = 'http://host.docker.internal:8000/SSBD/api/v3/'

urlbase = 'http://ssbd.qbic.riken.jp/SSBD/api/v3/'


apifunc = 'bd5coords/?'
# version 1.0
#urlbase = 'http://ssbd.qbic.riken.jp/SSBD/api/v1/'
#apifunc = 'coordsXYZ/?'
fmt = 'format=json;'
#lmt = 5000
#offst = 0
start = 0
stop = 100
timestep = 100
#resp = requests.get(urlbase+apifunc+fmt+'limit=50000;bdml__bdml_ID__icontains=d15115;t=2')
mainurl = urlbase+apifunc+fmt+'offset='+str(start)+';limit='+str(stop)+';bdmlID=800faa21-c28c-4b72-bd12-d41f2eed02e8'+';ts='+str(timestep)
print("mainurl=", mainurl)
resp = requests.get(mainurl)
print(resp)

if resp.status_code != 200:
    # This means something went wrong.
    raise ApiError('GET /tasks/ {}'.format(resp.status_code))

bdmldata = resp.json()
for i in bdmldata['objects']:
    print("i[x]=", i['x'])
    print("i[y]=", i['y'])
    print("i[z]=", i['z'])
    print("i[t]=", i['t'])
    print("i[radius]=", i['radius'])
    print("--------------")
# Out:
# (MainThread) Starting new HTTP connection (1): ssbd.qbic.riken.jp
# mainurl= http://ssbd.qbic.riken.jp/SSBD/api/v3/bd5coords/?format=json;offset=0;limit=100;bdmlID=800faa21-c28c-4b72-bd12-d41f2eed02e8;ts=100
# (MainThread) http://ssbd.qbic.riken.jp:80 "GET /SSBD/api/v3/bd5coords/?format=json;offset=0;limit=100;bdmlID=800faa21-c28c-4b72-bd12-d41f2eed02e8;ts=100 HTTP/1.1" 200 None
# <Response [200]>
# i[x]= 282.0
# i[y]= 282.0
# i[z]= 8.2
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 261.0
# i[y]= 184.0
# i[z]= 9.2
# i[t]= 101.0
# i[radius]= 2.07
# --------------
# i[x]= 509.0
# i[y]= 187.0
# i[z]= 9.1
# i[t]= 101.0
# i[radius]= 2.16
# --------------
# i[x]= 318.0
# i[y]= 194.0
# i[z]= 8.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 396.0
# i[y]= 210.0
# i[z]= 8.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 193.0
# i[y]= 229.0
# i[z]= 8.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 451.0
# i[y]= 278.0
# i[z]= 9.1
# i[t]= 101.0
# i[radius]= 2.16
# --------------
# i[x]= 228.0
# i[y]= 295.0
# i[z]= 9.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 365.0
# i[y]= 296.0
# i[z]= 9.1
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 173.0
# i[y]= 311.0
# i[z]= 9.1
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 220.0
# i[y]= 360.0
# i[z]= 9.2
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 518.0
# i[y]= 301.0
# i[z]= 10.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 389.0
# i[y]= 350.0
# i[z]= 10.1
# i[t]= 101.0
# i[radius]= 2.07
# --------------
# i[x]= 295.0
# i[y]= 396.0
# i[z]= 10.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 353.0
# i[y]= 399.0
# i[z]= 9.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 405.0
# i[y]= 112.0
# i[z]= 11.2
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 557.0
# i[y]= 250.0
# i[z]= 10.4
# i[t]= 101.0
# i[radius]= 2.16
# --------------
# i[x]= 294.0
# i[y]= 336.0
# i[z]= 10.4
# i[t]= 101.0
# i[radius]= 2.07
# --------------
# i[x]= 478.0
# i[y]= 125.0
# i[z]= 11.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 208.0
# i[y]= 146.0
# i[z]= 12.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 149.0
# i[y]= 194.0
# i[z]= 11.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 223.0
# i[y]= 252.0
# i[z]= 12.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 143.0
# i[y]= 261.0
# i[z]= 11.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 289.0
# i[y]= 264.0
# i[z]= 12.1
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 464.0
# i[y]= 360.0
# i[z]= 11.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 514.0
# i[y]= 376.0
# i[z]= 11.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 433.0
# i[y]= 408.0
# i[z]= 12.2
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 327.0
# i[y]= 113.0
# i[z]= 13.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 378.0
# i[y]= 158.0
# i[z]= 12.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 457.0
# i[y]= 176.0
# i[z]= 13.1
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 324.0
# i[y]= 168.0
# i[z]= 14.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 254.0
# i[y]= 185.0
# i[z]= 14.1
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 580.0
# i[y]= 203.0
# i[z]= 14.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 571.0
# i[y]= 345.0
# i[z]= 15.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 244.0
# i[y]= 411.0
# i[z]= 14.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 358.0
# i[y]= 244.0
# i[z]= 16.0
# i[t]= 101.0
# i[radius]= 2.16
# --------------
# i[x]= 454.0
# i[y]= 245.0
# i[z]= 16.1
# i[t]= 101.0
# i[radius]= 2.16
# --------------
# i[x]= 600.0
# i[y]= 288.0
# i[z]= 16.0
# i[t]= 101.0
# i[radius]= 2.07
# --------------
# i[x]= 196.0
# i[y]= 317.0
# i[z]= 16.1
# i[t]= 101.0
# i[radius]= 2.16
# --------------
# i[x]= 154.0
# i[y]= 365.0
# i[z]= 16.1
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 317.0
# i[y]= 386.0
# i[z]= 15.3
# i[t]= 101.0
# i[radius]= 2.07
# --------------
# i[x]= 435.0
# i[y]= 117.0
# i[z]= 16.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 501.0
# i[y]= 155.0
# i[z]= 16.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 202.0
# i[y]= 178.0
# i[z]= 17.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 180.0
# i[y]= 244.0
# i[z]= 17.1
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 113.0
# i[y]= 248.0
# i[z]= 16.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 260.0
# i[y]= 258.0
# i[z]= 17.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 453.0
# i[y]= 319.0
# i[z]= 17.0
# i[t]= 101.0
# i[radius]= 2.16
# --------------
# i[x]= 205.0
# i[y]= 387.0
# i[z]= 16.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 453.0
# i[y]= 414.0
# i[z]= 16.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 390.0
# i[y]= 424.0
# i[z]= 16.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 322.0
# i[y]= 431.0
# i[z]= 17.1
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 351.0
# i[y]= 104.0
# i[z]= 17.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 276.0
# i[y]= 112.0
# i[z]= 17.8
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 541.0
# i[y]= 207.0
# i[z]= 18.1
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 122.0
# i[y]= 305.0
# i[z]= 17.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 364.0
# i[y]= 322.0
# i[z]= 17.2
# i[t]= 101.0
# i[radius]= 2.16
# --------------
# i[x]= 258.0
# i[y]= 349.0
# i[z]= 17.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 356.0
# i[y]= 160.0
# i[z]= 19.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 510.0
# i[y]= 406.0
# i[z]= 19.1
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 199.0
# i[y]= 142.0
# i[z]= 20.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 554.0
# i[y]= 161.0
# i[z]= 20.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 137.0
# i[y]= 218.0
# i[z]= 20.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 428.0
# i[y]= 117.0
# i[z]= 21.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 488.0
# i[y]= 122.0
# i[z]= 22.1
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 253.0
# i[y]= 207.0
# i[z]= 22.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 306.0
# i[y]= 228.0
# i[z]= 21.1
# i[t]= 101.0
# i[radius]= 1.8
# --------------
# i[x]= 596.0
# i[y]= 235.0
# i[z]= 22.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 158.0
# i[y]= 337.0
# i[z]= 22.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 355.0
# i[y]= 383.0
# i[z]= 22.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 380.0
# i[y]= 207.0
# i[z]= 22.2
# i[t]= 101.0
# i[radius]= 1.8
# --------------
# i[x]= 249.0
# i[y]= 273.0
# i[z]= 22.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 160.0
# i[y]= 277.0
# i[z]= 23.1
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 563.0
# i[y]= 293.0
# i[z]= 23.1
# i[t]= 101.0
# i[radius]= 2.16
# --------------
# i[x]= 446.0
# i[y]= 329.0
# i[z]= 22.0
# i[t]= 101.0
# i[radius]= 2.16
# --------------
# i[x]= 530.0
# i[y]= 369.0
# i[z]= 22.1
# i[t]= 101.0
# i[radius]= 2.16
# --------------
# i[x]= 299.0
# i[y]= 381.0
# i[z]= 22.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 231.0
# i[y]= 383.0
# i[z]= 23.0
# i[t]= 101.0
# i[radius]= 2.07
# --------------
# i[x]= 417.0
# i[y]= 385.0
# i[z]= 22.1
# i[t]= 101.0
# i[radius]= 1.71
# --------------
# i[x]= 363.0
# i[y]= 114.0
# i[z]= 24.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 269.0
# i[y]= 138.0
# i[z]= 23.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 319.0
# i[y]= 142.0
# i[z]= 23.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 165.0
# i[y]= 206.0
# i[z]= 24.0
# i[t]= 101.0
# i[radius]= 2.07
# --------------
# i[x]= 331.0
# i[y]= 271.0
# i[z]= 24.1
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 504.0
# i[y]= 276.0
# i[z]= 24.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 346.0
# i[y]= 337.0
# i[z]= 24.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 533.0
# i[y]= 198.0
# i[z]= 25.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 454.0
# i[y]= 226.0
# i[z]= 25.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 401.0
# i[y]= 286.0
# i[z]= 25.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 258.0
# i[y]= 322.0
# i[z]= 24.9
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 423.0
# i[y]= 146.0
# i[z]= 26.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 484.0
# i[y]= 174.0
# i[z]= 26.0
# i[t]= 101.0
# i[radius]= 1.98
# --------------
# i[x]= 219.0
# i[y]= 178.0
# i[z]= 26.2
# i[t]= 101.0
# i[radius]= 2.16
# --------------
# i[x]= 164.0
# i[y]= 345.0
# i[z]= 6.9
# i[t]= 101.0
# i[radius]= 1.305
# --------------

# %%
# getting scaleUnit information
# version 3.2
#urlbase = 'http://ssbd1.qbic.riken.jp:8000/SSBD/api/v3/'
#urlbase = 'http://host.docker.internal:8000/SSBD/api/v3/'

urlbase = 'http://ssbd.qbic.riken.jp/SSBD/api/v3/'


apifunc = 'bd5scaleunit/?'
fmt = 'format=json;'

mainurl = urlbase+apifunc+fmt+';bdmlID=800faa21-c28c-4b72-bd12-d41f2eed02e8'+';'
print("mainurl=", mainurl)
resp = requests.get(mainurl)
print(resp)

if resp.status_code != 200:
    # This means something went wrong.
    raise ApiError('GET /tasks/ {}'.format(resp.status_code))

bdmlscaledata = resp.json()
bdmlscaledata
# Out:
# (MainThread) Starting new HTTP connection (1): ssbd.qbic.riken.jp
# mainurl= http://ssbd.qbic.riken.jp/SSBD/api/v3/bd5scaleunit/?format=json;;bdmlID=800faa21-c28c-4b72-bd12-d41f2eed02e8;
# (MainThread) http://ssbd.qbic.riken.jp:80 "GET /SSBD/api/v3/bd5scaleunit/?format=json;;bdmlID=800faa21-c28c-4b72-bd12-d41f2eed02e8; HTTP/1.1" 200 None
# <Response [200]>
# {'meta': {'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total_count': 1},
#  'objects': [{'dimension': '3D+T',
#    'sUnit': 'micrometer',
#    't': None,
#    'tUnit': 'minute',
#    'xScale': '0.09',
#    'yScale': '0.09',
#    'zScale': '1.0'}]}

# %%
xscale = float(bdmlscaledata['objects'][0]['xScale'])
yscale = float(bdmlscaledata['objects'][0]['yScale'])
zscale = float(bdmlscaledata['objects'][0]['zScale'])
print("xscale:", xscale, "yscale:", yscale, "zscale:", zscale)
# Out:
# xscale: 0.09 yscale: 0.09 zscale: 1.0

# %% [markdown]
# ## Display 3D positions

# %%
canvas(title="Displaying 3D graphics", background=(0.8,0.8,0.8) )
c = color.red
r = 0.1
x = 0
y = 0
Z = 0
# Out:
# <div id="scene0"><div id="glowscript" class="glowscript"></div></div>

# %%
#count =1
for i in bdmldata['objects']:
        print("is[x]=", float(i['x'])*xscale," is[y]=", float(i['y'])*yscale, "is[z]=", float(i['z'])*zscale, "i[t]=", i['t'], "i[radius]=", float(i['radius']))
        nucleus = sphere()
        nucleus.pos = vector(float(i['x'])*xscale, float(i['y'])*yscale, float(i['z'])*zscale)
        nucleus.size = float(i['radius'])*vector(1,1,1)
#        nucleus.size = count*2*vector(1,1,1)
        nucleus.color = c
#        count = count+1
# Out:
# is[x]= 25.38  is[y]= 25.38 is[z]= 8.2 i[t]= 101.0 i[radius]= 1.98
# is[x]= 23.49  is[y]= 16.56 is[z]= 9.2 i[t]= 101.0 i[radius]= 2.07
# is[x]= 45.809999999999995  is[y]= 16.83 is[z]= 9.1 i[t]= 101.0 i[radius]= 2.16
# is[x]= 28.619999999999997  is[y]= 17.46 is[z]= 8.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 35.64  is[y]= 18.9 is[z]= 8.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 17.37  is[y]= 20.61 is[z]= 8.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 40.589999999999996  is[y]= 25.02 is[z]= 9.1 i[t]= 101.0 i[radius]= 2.16
# is[x]= 20.52  is[y]= 26.55 is[z]= 9.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 32.85  is[y]= 26.64 is[z]= 9.1 i[t]= 101.0 i[radius]= 1.98
# is[x]= 15.57  is[y]= 27.99 is[z]= 9.1 i[t]= 101.0 i[radius]= 1.98
# is[x]= 19.8  is[y]= 32.4 is[z]= 9.2 i[t]= 101.0 i[radius]= 1.98
# is[x]= 46.62  is[y]= 27.09 is[z]= 10.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 35.01  is[y]= 31.5 is[z]= 10.1 i[t]= 101.0 i[radius]= 2.07
# is[x]= 26.55  is[y]= 35.64 is[z]= 10.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 31.77  is[y]= 35.91 is[z]= 9.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 36.449999999999996  is[y]= 10.08 is[z]= 11.2 i[t]= 101.0 i[radius]= 1.98
# is[x]= 50.129999999999995  is[y]= 22.5 is[z]= 10.4 i[t]= 101.0 i[radius]= 2.16
# is[x]= 26.459999999999997  is[y]= 30.24 is[z]= 10.4 i[t]= 101.0 i[radius]= 2.07
# is[x]= 43.019999999999996  is[y]= 11.25 is[z]= 11.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 18.72  is[y]= 13.139999999999999 is[z]= 12.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 13.41  is[y]= 17.46 is[z]= 11.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 20.07  is[y]= 22.68 is[z]= 12.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 12.87  is[y]= 23.49 is[z]= 11.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 26.009999999999998  is[y]= 23.759999999999998 is[z]= 12.1 i[t]= 101.0 i[radius]= 1.98
# is[x]= 41.76  is[y]= 32.4 is[z]= 11.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 46.26  is[y]= 33.839999999999996 is[z]= 11.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 38.97  is[y]= 36.72 is[z]= 12.2 i[t]= 101.0 i[radius]= 1.98
# is[x]= 29.43  is[y]= 10.17 is[z]= 13.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 34.019999999999996  is[y]= 14.219999999999999 is[z]= 12.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 41.129999999999995  is[y]= 15.84 is[z]= 13.1 i[t]= 101.0 i[radius]= 1.98
# is[x]= 29.16  is[y]= 15.12 is[z]= 14.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 22.86  is[y]= 16.65 is[z]= 14.1 i[t]= 101.0 i[radius]= 1.98
# is[x]= 52.199999999999996  is[y]= 18.27 is[z]= 14.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 51.39  is[y]= 31.049999999999997 is[z]= 15.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 21.96  is[y]= 36.99 is[z]= 14.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 32.22  is[y]= 21.96 is[z]= 16.0 i[t]= 101.0 i[radius]= 2.16
# is[x]= 40.86  is[y]= 22.05 is[z]= 16.1 i[t]= 101.0 i[radius]= 2.16
# is[x]= 54.0  is[y]= 25.919999999999998 is[z]= 16.0 i[t]= 101.0 i[radius]= 2.07
# is[x]= 17.64  is[y]= 28.529999999999998 is[z]= 16.1 i[t]= 101.0 i[radius]= 2.16
# is[x]= 13.86  is[y]= 32.85 is[z]= 16.1 i[t]= 101.0 i[radius]= 1.98
# is[x]= 28.529999999999998  is[y]= 34.74 is[z]= 15.3 i[t]= 101.0 i[radius]= 2.07
# is[x]= 39.15  is[y]= 10.53 is[z]= 16.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 45.089999999999996  is[y]= 13.95 is[z]= 16.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 18.18  is[y]= 16.02 is[z]= 17.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 16.2  is[y]= 21.96 is[z]= 17.1 i[t]= 101.0 i[radius]= 1.98
# is[x]= 10.17  is[y]= 22.32 is[z]= 16.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 23.4  is[y]= 23.22 is[z]= 17.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 40.769999999999996  is[y]= 28.709999999999997 is[z]= 17.0 i[t]= 101.0 i[radius]= 2.16
# is[x]= 18.45  is[y]= 34.83 is[z]= 16.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 40.769999999999996  is[y]= 37.26 is[z]= 16.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 35.1  is[y]= 38.16 is[z]= 16.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 28.98  is[y]= 38.79 is[z]= 17.1 i[t]= 101.0 i[radius]= 1.98
# is[x]= 31.59  is[y]= 9.36 is[z]= 17.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 24.84  is[y]= 10.08 is[z]= 17.8 i[t]= 101.0 i[radius]= 1.98
# is[x]= 48.69  is[y]= 18.63 is[z]= 18.1 i[t]= 101.0 i[radius]= 1.98
# is[x]= 10.98  is[y]= 27.45 is[z]= 17.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 32.76  is[y]= 28.98 is[z]= 17.2 i[t]= 101.0 i[radius]= 2.16
# is[x]= 23.22  is[y]= 31.41 is[z]= 17.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 32.04  is[y]= 14.399999999999999 is[z]= 19.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 45.9  is[y]= 36.54 is[z]= 19.1 i[t]= 101.0 i[radius]= 1.98
# is[x]= 17.91  is[y]= 12.78 is[z]= 20.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 49.86  is[y]= 14.49 is[z]= 20.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 12.33  is[y]= 19.62 is[z]= 20.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 38.519999999999996  is[y]= 10.53 is[z]= 21.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 43.92  is[y]= 10.98 is[z]= 22.1 i[t]= 101.0 i[radius]= 1.98
# is[x]= 22.77  is[y]= 18.63 is[z]= 22.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 27.54  is[y]= 20.52 is[z]= 21.1 i[t]= 101.0 i[radius]= 1.8
# is[x]= 53.64  is[y]= 21.15 is[z]= 22.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 14.219999999999999  is[y]= 30.33 is[z]= 22.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 31.95  is[y]= 34.47 is[z]= 22.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 34.199999999999996  is[y]= 18.63 is[z]= 22.2 i[t]= 101.0 i[radius]= 1.8
# is[x]= 22.41  is[y]= 24.57 is[z]= 22.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 14.399999999999999  is[y]= 24.93 is[z]= 23.1 i[t]= 101.0 i[radius]= 1.98
# is[x]= 50.669999999999995  is[y]= 26.369999999999997 is[z]= 23.1 i[t]= 101.0 i[radius]= 2.16
# is[x]= 40.14  is[y]= 29.61 is[z]= 22.0 i[t]= 101.0 i[radius]= 2.16
# is[x]= 47.699999999999996  is[y]= 33.21 is[z]= 22.1 i[t]= 101.0 i[radius]= 2.16
# is[x]= 26.91  is[y]= 34.29 is[z]= 22.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 20.79  is[y]= 34.47 is[z]= 23.0 i[t]= 101.0 i[radius]= 2.07
# is[x]= 37.53  is[y]= 34.65 is[z]= 22.1 i[t]= 101.0 i[radius]= 1.71
# is[x]= 32.67  is[y]= 10.26 is[z]= 24.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 24.21  is[y]= 12.42 is[z]= 23.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 28.709999999999997  is[y]= 12.78 is[z]= 23.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 14.85  is[y]= 18.54 is[z]= 24.0 i[t]= 101.0 i[radius]= 2.07
# is[x]= 29.79  is[y]= 24.39 is[z]= 24.1 i[t]= 101.0 i[radius]= 1.98
# is[x]= 45.36  is[y]= 24.84 is[z]= 24.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 31.14  is[y]= 30.33 is[z]= 24.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 47.97  is[y]= 17.82 is[z]= 25.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 40.86  is[y]= 20.34 is[z]= 25.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 36.089999999999996  is[y]= 25.74 is[z]= 25.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 23.22  is[y]= 28.98 is[z]= 24.9 i[t]= 101.0 i[radius]= 1.98
# is[x]= 38.07  is[y]= 13.139999999999999 is[z]= 26.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 43.559999999999995  is[y]= 15.66 is[z]= 26.0 i[t]= 101.0 i[radius]= 1.98
# is[x]= 19.71  is[y]= 16.02 is[z]= 26.2 i[t]= 101.0 i[radius]= 2.16
# is[x]= 14.76  is[y]= 31.049999999999997 is[z]= 6.9 i[t]= 101.0 i[radius]= 1.305

# %%
bdmldata
# Out:
# {'meta': {'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total_count': 94},
#  'objects': [{'entity': 'sphere',
#    'id': '101001',
#    'label': 'ABplapaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '282.0',
#    'y': '282.0',
#    'z': '8.2'},
#   {'entity': 'sphere',
#    'id': '101002',
#    'label': 'ABarpaap',
#    'radius': '2.07',
#    'sid': None,
#    't': '101.0',
#    'x': '261.0',
#    'y': '184.0',
#    'z': '9.2'},
#   {'entity': 'sphere',
#    'id': '101003',
#    'label': 'Cpaa',
#    'radius': '2.16',
#    'sid': None,
#    't': '101.0',
#    'x': '509.0',
#    'y': '187.0',
#    'z': '9.1'},
#   {'entity': 'sphere',
#    'id': '101004',
#    'label': 'ABarppaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '318.0',
#    'y': '194.0',
#    'z': '8.9'},
#   {'entity': 'sphere',
#    'id': '101005',
#    'label': 'ABarppap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '396.0',
#    'y': '210.0',
#    'z': '8.9'},
#   {'entity': 'sphere',
#    'id': '101006',
#    'label': 'ABallpap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '193.0',
#    'y': '229.0',
#    'z': '8.9'},
#   {'entity': 'sphere',
#    'id': '101007',
#    'label': 'Caaa',
#    'radius': '2.16',
#    'sid': None,
#    't': '101.0',
#    'x': '451.0',
#    'y': '278.0',
#    'z': '9.1'},
#   {'entity': 'sphere',
#    'id': '101008',
#    'label': 'ABplaaap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '228.0',
#    'y': '295.0',
#    'z': '9.0'},
#   {'entity': 'sphere',
#    'id': '101009',
#    'label': 'ABplapap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '365.0',
#    'y': '296.0',
#    'z': '9.1'},
#   {'entity': 'sphere',
#    'id': '101010',
#    'label': 'ABplaaaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '173.0',
#    'y': '311.0',
#    'z': '9.1'},
#   {'entity': 'sphere',
#    'id': '101011',
#    'label': 'ABplaapa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '220.0',
#    'y': '360.0',
#    'z': '9.2'},
#   {'entity': 'sphere',
#    'id': '101012',
#    'label': 'Caap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '518.0',
#    'y': '301.0',
#    'z': '10.0'},
#   {'entity': 'sphere',
#    'id': '101013',
#    'label': 'ABplappa',
#    'radius': '2.07',
#    'sid': None,
#    't': '101.0',
#    'x': '389.0',
#    'y': '350.0',
#    'z': '10.1'},
#   {'entity': 'sphere',
#    'id': '101014',
#    'label': 'ABplpaap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '295.0',
#    'y': '396.0',
#    'z': '10.0'},
#   {'entity': 'sphere',
#    'id': '101015',
#    'label': 'ABplppaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '353.0',
#    'y': '399.0',
#    'z': '9.9'},
#   {'entity': 'sphere',
#    'id': '101016',
#    'label': 'ABprapaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '405.0',
#    'y': '112.0',
#    'z': '11.2'},
#   {'entity': 'sphere',
#    'id': '101017',
#    'label': 'Cpap',
#    'radius': '2.16',
#    'sid': None,
#    't': '101.0',
#    'x': '557.0',
#    'y': '250.0',
#    'z': '10.4'},
#   {'entity': 'sphere',
#    'id': '101018',
#    'label': 'ABplaapp',
#    'radius': '2.07',
#    'sid': None,
#    't': '101.0',
#    'x': '294.0',
#    'y': '336.0',
#    'z': '10.4'},
#   {'entity': 'sphere',
#    'id': '101019',
#    'label': 'ABprapap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '478.0',
#    'y': '125.0',
#    'z': '11.9'},
#   {'entity': 'sphere',
#    'id': '101020',
#    'label': 'ABarpaaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '208.0',
#    'y': '146.0',
#    'z': '12.0'},
#   {'entity': 'sphere',
#    'id': '101021',
#    'label': 'ABallpaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '149.0',
#    'y': '194.0',
#    'z': '11.9'},
#   {'entity': 'sphere',
#    'id': '101022',
#    'label': 'ABallppa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '223.0',
#    'y': '252.0',
#    'z': '12.0'},
#   {'entity': 'sphere',
#    'id': '101023',
#    'label': 'ABallaap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '143.0',
#    'y': '261.0',
#    'z': '11.9'},
#   {'entity': 'sphere',
#    'id': '101024',
#    'label': 'ABallppp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '289.0',
#    'y': '264.0',
#    'z': '12.1'},
#   {'entity': 'sphere',
#    'id': '101025',
#    'label': 'ABplappp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '464.0',
#    'y': '360.0',
#    'z': '11.9'},
#   {'entity': 'sphere',
#    'id': '101026',
#    'label': 'Capa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '514.0',
#    'y': '376.0',
#    'z': '11.9'},
#   {'entity': 'sphere',
#    'id': '101027',
#    'label': 'ABplppap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '433.0',
#    'y': '408.0',
#    'z': '12.2'},
#   {'entity': 'sphere',
#    'id': '101028',
#    'label': 'ABpraaap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '327.0',
#    'y': '113.0',
#    'z': '13.0'},
#   {'entity': 'sphere',
#    'id': '101029',
#    'label': 'ABarpppa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '378.0',
#    'y': '158.0',
#    'z': '12.9'},
#   {'entity': 'sphere',
#    'id': '101030',
#    'label': 'ABarpppp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '457.0',
#    'y': '176.0',
#    'z': '13.1'},
#   {'entity': 'sphere',
#    'id': '101031',
#    'label': 'ABarpapp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '324.0',
#    'y': '168.0',
#    'z': '14.0'},
#   {'entity': 'sphere',
#    'id': '101032',
#    'label': 'ABarpapa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '254.0',
#    'y': '185.0',
#    'z': '14.1'},
#   {'entity': 'sphere',
#    'id': '101033',
#    'label': 'Cppr',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '580.0',
#    'y': '203.0',
#    'z': '14.0'},
#   {'entity': 'sphere',
#    'id': '101034',
#    'label': 'Capp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '571.0',
#    'y': '345.0',
#    'z': '15.0'},
#   {'entity': 'sphere',
#    'id': '101035',
#    'label': 'ABplpaaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '244.0',
#    'y': '411.0',
#    'z': '14.9'},
#   {'entity': 'sphere',
#    'id': '101036',
#    'label': 'Eaa',
#    'radius': '2.16',
#    'sid': None,
#    't': '101.0',
#    'x': '358.0',
#    'y': '244.0',
#    'z': '16.0'},
#   {'entity': 'sphere',
#    'id': '101037',
#    'label': 'Epr',
#    'radius': '2.16',
#    'sid': None,
#    't': '101.0',
#    'x': '454.0',
#    'y': '245.0',
#    'z': '16.1'},
#   {'entity': 'sphere',
#    'id': '101038',
#    'label': 'Cppl',
#    'radius': '2.07',
#    'sid': None,
#    't': '101.0',
#    'x': '600.0',
#    'y': '288.0',
#    'z': '16.0'},
#   {'entity': 'sphere',
#    'id': '101039',
#    'label': 'ABalraap',
#    'radius': '2.16',
#    'sid': None,
#    't': '101.0',
#    'x': '196.0',
#    'y': '317.0',
#    'z': '16.1'},
#   {'entity': 'sphere',
#    'id': '101040',
#    'label': 'ABalrpaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '154.0',
#    'y': '365.0',
#    'z': '16.1'},
#   {'entity': 'sphere',
#    'id': '101041',
#    'label': 'ABalrppp',
#    'radius': '2.07',
#    'sid': None,
#    't': '101.0',
#    'x': '317.0',
#    'y': '386.0',
#    'z': '15.3'},
#   {'entity': 'sphere',
#    'id': '101042',
#    'label': 'ABpraapp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '435.0',
#    'y': '117.0',
#    'z': '16.9'},
#   {'entity': 'sphere',
#    'id': '101043',
#    'label': 'ABprappa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '501.0',
#    'y': '155.0',
#    'z': '16.9'},
#   {'entity': 'sphere',
#    'id': '101044',
#    'label': 'ABaraaap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '202.0',
#    'y': '178.0',
#    'z': '17.0'},
#   {'entity': 'sphere',
#    'id': '101045',
#    'label': 'ABallapa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '180.0',
#    'y': '244.0',
#    'z': '17.1'},
#   {'entity': 'sphere',
#    'id': '101046',
#    'label': 'ABallaaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '113.0',
#    'y': '248.0',
#    'z': '16.9'},
#   {'entity': 'sphere',
#    'id': '101047',
#    'label': 'ABallapp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '260.0',
#    'y': '258.0',
#    'z': '17.0'},
#   {'entity': 'sphere',
#    'id': '101048',
#    'label': 'Epl',
#    'radius': '2.16',
#    'sid': None,
#    't': '101.0',
#    'x': '453.0',
#    'y': '319.0',
#    'z': '17.0'},
#   {'entity': 'sphere',
#    'id': '101049',
#    'label': 'ABalrpap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '205.0',
#    'y': '387.0',
#    'z': '16.9'},
#   {'entity': 'sphere',
#    'id': '101050',
#    'label': 'ABplpppa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '453.0',
#    'y': '414.0',
#    'z': '16.9'},
#   {'entity': 'sphere',
#    'id': '101051',
#    'label': 'ABplpapp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '390.0',
#    'y': '424.0',
#    'z': '16.9'},
#   {'entity': 'sphere',
#    'id': '101052',
#    'label': 'ABplpapa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '322.0',
#    'y': '431.0',
#    'z': '17.1'},
#   {'entity': 'sphere',
#    'id': '101053',
#    'label': 'ABpraapa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '351.0',
#    'y': '104.0',
#    'z': '17.9'},
#   {'entity': 'sphere',
#    'id': '101054',
#    'label': 'ABpraaaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '276.0',
#    'y': '112.0',
#    'z': '17.8'},
#   {'entity': 'sphere',
#    'id': '101055',
#    'label': 'ABprappp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '541.0',
#    'y': '207.0',
#    'z': '18.1'},
#   {'entity': 'sphere',
#    'id': '101056',
#    'label': 'ABalraaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '122.0',
#    'y': '305.0',
#    'z': '17.9'},
#   {'entity': 'sphere',
#    'id': '101057',
#    'label': 'Eap',
#    'radius': '2.16',
#    'sid': None,
#    't': '101.0',
#    'x': '364.0',
#    'y': '322.0',
#    'z': '17.2'},
#   {'entity': 'sphere',
#    'id': '101058',
#    'label': 'ABalrppa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '258.0',
#    'y': '349.0',
#    'z': '17.9'},
#   {'entity': 'sphere',
#    'id': '101059',
#    'label': 'ABarappp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '356.0',
#    'y': '160.0',
#    'z': '19.0'},
#   {'entity': 'sphere',
#    'id': '101060',
#    'label': 'ABplpppp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '510.0',
#    'y': '406.0',
#    'z': '19.1'},
#   {'entity': 'sphere',
#    'id': '101061',
#    'label': 'ABarapaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '199.0',
#    'y': '142.0',
#    'z': '20.9'},
#   {'entity': 'sphere',
#    'id': '101062',
#    'label': 'ABprppap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '554.0',
#    'y': '161.0',
#    'z': '20.9'},
#   {'entity': 'sphere',
#    'id': '101063',
#    'label': 'ABaraaaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '137.0',
#    'y': '218.0',
#    'z': '20.9'},
#   {'entity': 'sphere',
#    'id': '101064',
#    'label': 'ABprpaap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '428.0',
#    'y': '117.0',
#    'z': '21.9'},
#   {'entity': 'sphere',
#    'id': '101065',
#    'label': 'ABprppaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '488.0',
#    'y': '122.0',
#    'z': '22.1'},
#   {'entity': 'sphere',
#    'id': '101066',
#    'label': 'MSpaaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '253.0',
#    'y': '207.0',
#    'z': '22.0'},
#   {'entity': 'sphere',
#    'id': '101067',
#    'label': 'MSpaap',
#    'radius': '1.8',
#    'sid': None,
#    't': '101.0',
#    'x': '306.0',
#    'y': '228.0',
#    'z': '21.1'},
#   {'entity': 'sphere',
#    'id': '101068',
#    'label': 'ABprpppl',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '596.0',
#    'y': '235.0',
#    'z': '22.0'},
#   {'entity': 'sphere',
#    'id': '101069',
#    'label': 'ABalrapa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '158.0',
#    'y': '337.0',
#    'z': '22.0'},
#   {'entity': 'sphere',
#    'id': '101070',
#    'label': 'MSapap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '355.0',
#    'y': '383.0',
#    'z': '22.0'},
#   {'entity': 'sphere',
#    'id': '101071',
#    'label': 'MSppa',
#    'radius': '1.8',
#    'sid': None,
#    't': '101.0',
#    'x': '380.0',
#    'y': '207.0',
#    'z': '22.2'},
#   {'entity': 'sphere',
#    'id': '101072',
#    'label': 'MSaaap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '249.0',
#    'y': '273.0',
#    'z': '22.9'},
#   {'entity': 'sphere',
#    'id': '101073',
#    'label': 'MSaaaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '160.0',
#    'y': '277.0',
#    'z': '23.1'},
#   {'entity': 'sphere',
#    'id': '101074',
#    'label': 'Dp',
#    'radius': '2.16',
#    'sid': None,
#    't': '101.0',
#    'x': '563.0',
#    'y': '293.0',
#    'z': '23.1'},
#   {'entity': 'sphere',
#    'id': '101075',
#    'label': 'Z3',
#    'radius': '2.16',
#    'sid': None,
#    't': '101.0',
#    'x': '446.0',
#    'y': '329.0',
#    'z': '22.0'},
#   {'entity': 'sphere',
#    'id': '101076',
#    'label': 'Da',
#    'radius': '2.16',
#    'sid': None,
#    't': '101.0',
#    'x': '530.0',
#    'y': '369.0',
#    'z': '22.1'},
#   {'entity': 'sphere',
#    'id': '101077',
#    'label': 'MSapaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '299.0',
#    'y': '381.0',
#    'z': '22.9'},
#   {'entity': 'sphere',
#    'id': '101078',
#    'label': 'ABalrapp',
#    'radius': '2.07',
#    'sid': None,
#    't': '101.0',
#    'x': '231.0',
#    'y': '383.0',
#    'z': '23.0'},
#   {'entity': 'sphere',
#    'id': '101079',
#    'label': 'MSapp',
#    'radius': '1.71',
#    'sid': None,
#    't': '101.0',
#    'x': '417.0',
#    'y': '385.0',
#    'z': '22.1'},
#   {'entity': 'sphere',
#    'id': '101080',
#    'label': 'ABprpaaa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '363.0',
#    'y': '114.0',
#    'z': '24.0'},
#   {'entity': 'sphere',
#    'id': '101081',
#    'label': 'ABarapap',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '269.0',
#    'y': '138.0',
#    'z': '23.9'},
#   {'entity': 'sphere',
#    'id': '101082',
#    'label': 'ABarappa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '319.0',
#    'y': '142.0',
#    'z': '23.9'},
#   {'entity': 'sphere',
#    'id': '101083',
#    'label': 'ABaraapa',
#    'radius': '2.07',
#    'sid': None,
#    't': '101.0',
#    'x': '165.0',
#    'y': '206.0',
#    'z': '24.0'},
#   {'entity': 'sphere',
#    'id': '101084',
#    'label': 'MSpapa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '331.0',
#    'y': '271.0',
#    'z': '24.1'},
#   {'entity': 'sphere',
#    'id': '101085',
#    'label': 'Z2',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '504.0',
#    'y': '276.0',
#    'z': '24.0'},
#   {'entity': 'sphere',
#    'id': '101086',
#    'label': 'MSaapp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '346.0',
#    'y': '337.0',
#    'z': '24.0'},
#   {'entity': 'sphere',
#    'id': '101087',
#    'label': 'ABprpppr',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '533.0',
#    'y': '198.0',
#    'z': '25.0'},
#   {'entity': 'sphere',
#    'id': '101088',
#    'label': 'MSppp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '454.0',
#    'y': '226.0',
#    'z': '25.0'},
#   {'entity': 'sphere',
#    'id': '101089',
#    'label': 'MSpapp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '401.0',
#    'y': '286.0',
#    'z': '25.0'},
#   {'entity': 'sphere',
#    'id': '101090',
#    'label': 'MSaapa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '258.0',
#    'y': '322.0',
#    'z': '24.9'},
#   {'entity': 'sphere',
#    'id': '101091',
#    'label': 'ABprpapa',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '423.0',
#    'y': '146.0',
#    'z': '26.0'},
#   {'entity': 'sphere',
#    'id': '101092',
#    'label': 'ABprpapp',
#    'radius': '1.98',
#    'sid': None,
#    't': '101.0',
#    'x': '484.0',
#    'y': '174.0',
#    'z': '26.0'},
#   {'entity': 'sphere',
#    'id': '101093',
#    'label': 'ABaraapp',
#    'radius': '2.16',
#    'sid': None,
#    't': '101.0',
#    'x': '219.0',
#    'y': '178.0',
#    'z': '26.2'},
#   {'entity': 'sphere',
#    'id': '101094',
#    'label': 'polar1',
#    'radius': '1.305',
#    'sid': None,
#    't': '101.0',
#    'x': '164.0',
#    'y': '345.0',
#    'z': '6.9'}]}

# %%
len(bdmldata['objects'])
# Out:
# 94

# %%
i0 = bdmldata['objects'][0]
i0

# %%
i1 = bdmldata['objects'][2]
i1
